# %% [markdown]
# # Немного о запрещенном
# Небольшой проект, посвященный анализу [федерального списка экстремистских материалов](http://minjust.ru/ru/extremist-materials)

# %%
import sys
sys.path.append('/Users/dmitrys/anaconda2/lib/python2.7/site-packages')
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from wordcloud import WordCloud
from docx import Document

from nltk import FreqDist

# %%
document_name='ekstremizm_2_6_3_1_0_0_1_7_1.docx'

# %%
document = Document(document_name)

# %%
document.tables
# Out:
# [<docx.table.Table at 0x118caa390>,
#  <docx.table.Table at 0x118caa190>,
#  <docx.table.Table at 0x118caacd0>,
#  <docx.table.Table at 0x118caa350>,
#  <docx.table.Table at 0x118caa110>,
#  <docx.table.Table at 0x118caa950>,
#  <docx.table.Table at 0x118caabd0>,
#  <docx.table.Table at 0x118caa250>]

# %%
def readWordTable(document_name='ekstremizm_2_6_3_1_0_0_1_7_1 copy.docx'):
    document = Document(document_name)
    data = []
    
    for table in document.tables:
        #table = document.tables[0]

        # Data will be a list of rows represented as dictionaries
        # containing each row's data.


        keys = None
        for i, row in enumerate(table.rows):
            text = (cell.text for cell in row.cells)

            # Establish the mapping based on the first row
            # headers; these will become the keys of our dictionary
            if i == 0:
                keys = tuple(text)
                continue

            # Construct a dictionary for this row, mapping
            # keys to values for this row
            row_data = tuple(text)
            data.append(row_data)
    return data

# %%
data = readWordTable()

# %%
len(data)
# Out:
# 4041

# %%
print(data[1][1])
# Out:
# Письма Рады земли Кубанской духовно-родовой державы Русь, авторы - Н.М. Лозинский, В.М. Герасев, решение вынесено Первомайским районным судом г. Краснодара от 20.03.2006;

# %%
text.head()
# Out:
#                                                    1     2     3     4     5  \
# 0  Книга "Книга единобожия", автор - Мухаммад ибн...  None  None  None  None
# 1  Письма Рады земли Кубанской духовно-родовой де...  None  None  None  None
# 2  Печатные материалы в газете "Для русских людей...  None  None  None  None
# 3  Кинофильм "Вечный жид", решение вынесено Тихви...  None  None  None  None
# 4  Брошюра "Мать-земля: чудо-чудное, диво-дивное....  None  None  None  None
#
#       6     7
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None

# %%
final = pd.DataFrame()
for i in text.columns:
    final = pd.concat([final, text[i][~text[i].isnull()]], ignore_index=True)

# %%
final.head()
# Out:
#                                                    0
# 0  Книга "Книга единобожия", автор - Мухаммад ибн...
# 1  Письма Рады земли Кубанской духовно-родовой де...
# 2  Печатные материалы в газете "Для русских людей...
# 3  Кинофильм "Вечный жид", решение вынесено Тихви...
# 4  Брошюра "Мать-земля: чудо-чудное, диво-дивное....

# %%
final.tail()
# Out:
#                                                        0
# 11541  Информационный материал - текст музыкально-тек...
# 11542  Информационные материалы, размещенные в статье...
# 11543                                              2942.
# 11544  Текстовый документ, распространенный Стригунов...
# 11545  Информационный материал – текст музыкальной ко...

# %%
text = final.copy()

# %%
#text = pd.DataFrame(data).drop([0], axis=1)
text.columns = ["banned"]

from pymystem3 import Mystem

m = Mystem()
def lemmatize(text, mystem=m):
    try:
        return "".join(m.lemmatize(text)).strip()  
    except:
        return " "

text.banned = text.banned.apply(lemmatize)

# %%
text.head()
# Out:
#                                               banned
# 0  книга "книга единобожие", автор - мухаммад ибн...
# 1  письмо рад земля кубанский духовно-родовой дер...
# 2  печатный материал в газета "для русский челове...
# 3  кинофильм "вечный жид", решение вынести тихвин...
# 4  брошюра "мать-земля: чудо-чудный, диво-дивный....

# %%
from nltk.corpus import stopwords
mystopwords = stopwords.words('russian') + "сеть размещать суд городской районный москва интернет вконтакте социальный электронный адрес год решение wmv jpg республика длительность \
минута заканчиваться начинаться".split()

# %%
def  remove_stopwords(text, mystopwords = mystopwords):
    try:
        return " ".join([token.decode('utf-8') for token in text.split() if not token in mystopwords])
    except:
        return ""

text.banned = text.banned.apply(remove_stopwords)
# Out:
# /Users/dmitrys/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   app.launch_new_instance()

# %%
text.head()
# Out:
#                                               banned
# 0  книга "книга единобожие", автор - мухаммад ибн...
# 1  письмо рад земля кубанский духовно-родовой дер...
# 2  печатный материал газета "для русский человек"...
# 3  кинофильм "вечный жид", вынести тихвинский лен...
# 4  брошюра "мать-земля: чудо-чудный, диво-дивный....

# %%
text.tail()
# Out:
#                                                   banned
# 11541  информационный материал - текст музыкально-тек...
# 11542  информационный материал, статья «взлет падение...
# 11543                                              2942.
# 11544  текстовый документ, распространять стригунов и...
# 11545  информационный материал – текст музыкальный ко...

# %%
import string
def cleanString(myString):
    return myString.encode('utf-8').translate(None, string.punctuation).decode('utf-8')

text.banned = text.banned.apply(cleanString)

# %%
text.head()
# Out:
#                                               banned
# 0  книга книга единобожие автор  мухаммад ибн сул...
# 1  письмо рад земля кубанский духовнородовой держ...
# 2  печатный материал в газета для русский человек...
# 3  кинофильм вечный жид решение вынести тихвински...
# 4  брошюра матьземля чудочудный диводивный введен...

# %%
lemmata = []
for i in range(len(text)):
    lemmata += text.banned.iloc[i].split()
fd = FreqDist(lemmata)

# %%
for i in fd.most_common(10):
    print(i[0])
# Out:
# от
# суд
# решение
# районный
# в
# на
# г
# и
# размещать
# сеть

# %%
cloud = ''
for i in text.banned:
    cloud += (' '+i)

# %%
common = " ".join([i[0] for i in fd.most_common(150)])

# %%
print(common)
# Out:
# от суд решение районный в на г и размещать сеть с по – адрес интернет городской под страница материал сайт информационный город область республика изображение слово текст название москва социальный электронный год статья видеоролик надпись русский который «интернет» № к «вконтакте» продолжительность не книга ленинский определение минута из секунда видеофайл начинаться группа интернетсайт автор пользователь советский а видеоматериал за заканчиваться видеозапись для центральный «в издание мина «русский сечь располагать край интернетстраница санктпетербург человек опубликовывать со быть октябрьский брошюра информационныйтелекоммуникационный 1 аудиозапись издательство белый фотография газета 2 лицо длительность кировский контакт» автономный 3 песня печатный часть файл они округ листовка журнал мы россия рисунок о черный дело мужчина россия» аудиофайл имя международный содержать фон интернетресурс как «обращение 2011 чита гражданский судебный коллегия я казань текстовый это иметь что башкортостан весь ты рука ямалоненецкий цвет «россия новосибирск вид московский русский» информация содержаться убивать телекоммуникационный размер ресурс себя свой 4 графический он наш

# %%
cloud = " ".join([word for word in cloud.split() if word not in common])

# %%
from PIL import Image
pic = np.array(Image.open("LOVE.jpg"))
#mask = np.array(pic.getdata()).reshape(pic.size[0], pic.size[1], 2)

# %%
wordcloud = WordCloud(background_color="white", max_words=200, width=900, height=900)
wordcloud = wordcloud.generate(cloud)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear',)
plt.axis("off");

# %%
wordcloud = WordCloud(background_color="white", max_words=500, mask=pic, colormap='Reds')
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=2400x1500 at 0x123911650>
